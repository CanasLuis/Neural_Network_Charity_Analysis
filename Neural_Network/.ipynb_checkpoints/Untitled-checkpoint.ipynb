# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 841us/step - loss: 0.8498 - accuracy: 0.1427
# Epoch 2/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.8214 - accuracy: 0.1507
# Epoch 3/100
# 24/24 [==============================] - 0s 674us/step - loss: 0.7967 - accuracy: 0.1720
# Epoch 4/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.7755 - accuracy: 0.2013
# Epoch 5/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.7581 - accuracy: 0.2333
# Epoch 6/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.7431 - accuracy: 0.2520
# Epoch 7/100
# 24/24 [==============================] - 0s 878us/step - loss: 0.7307 - accuracy: 0.2853
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7208 - accuracy: 0.3200
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7124 - accuracy: 0.3707
# Epoch 10/100
# 24/24 [==============================] - 0s 891us/step - loss: 0.7067 - accuracy: 0.3960
# Epoch 11/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.7024 - accuracy: 0.4280
# Epoch 12/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6993 - accuracy: 0.4453
# Epoch 13/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6965 - accuracy: 0.4707
# Epoch 14/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6944 - accuracy: 0.4853
# Epoch 15/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6926 - accuracy: 0.5093
# Epoch 16/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6910 - accuracy: 0.5280
# Epoch 17/100
# 24/24 [==============================] - 0s 775us/step - loss: 0.6894 - accuracy: 0.5547
# Epoch 18/100
# 24/24 [==============================] - 0s 699us/step - loss: 0.6875 - accuracy: 0.5867
# Epoch 19/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6850 - accuracy: 0.6240
# Epoch 20/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.6816 - accuracy: 0.6547
# Epoch 21/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6769 - accuracy: 0.7053
# Epoch 22/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6696 - accuracy: 0.7627
# Epoch 23/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.6582 - accuracy: 0.8413
# Epoch 24/100
# 24/24 [==============================] - 0s 764us/step - loss: 0.6405 - accuracy: 0.9267
# Epoch 25/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6163 - accuracy: 0.9853
# Epoch 26/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.5900 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.5647 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.5407 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 699us/step - loss: 0.5181 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 720us/step - loss: 0.4966 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.4765 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.4572 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.4393 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 840us/step - loss: 0.4223 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.4063 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.3913 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.3772 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.3639 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 828us/step - loss: 0.3514 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 697us/step - loss: 0.3396 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.3284 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.3179 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.3080 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.2986 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.2897 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 794us/step - loss: 0.2812 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 731us/step - loss: 0.2732 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.2655 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.2582 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 771us/step - loss: 0.2512 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.2446 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.2382 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.2321 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 744us/step - loss: 0.2264 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.2208 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.2155 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.2104 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.2054 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.2007 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1961 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1918 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 734us/step - loss: 0.1875 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1834 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.1794 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.1756 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 740us/step - loss: 0.1719 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.1684 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1650 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1616 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1584 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1552 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 704us/step - loss: 0.1521 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 740us/step - loss: 0.1492 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.1463 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.1435 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 705us/step - loss: 0.1408 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1381 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.1355 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.1330 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 740us/step - loss: 0.1306 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1282 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1259 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 779us/step - loss: 0.1236 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.1214 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 740us/step - loss: 0.1193 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1172 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1152 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.1132 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1113 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1094 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 653us/step - loss: 0.1075 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1057 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 676us/step - loss: 0.1040 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.1022 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.1006 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.0989 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.0973 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 652us/step - loss: 0.0958 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 662us/step - loss: 0.0942 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 696us/step - loss: 0.0927 - accuracy: 1.0000

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0948 - accuracy: 1.0000 - 77ms/epoch - 10ms/step
# Loss: 0.0947626531124115, Accuracy: 1.0

# %%
# Predict the classification of a new set of blob data
new_X, new_Y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=78)
new_X_scaled = X_scaler.transform(new_X)
(nn_model.predict(new_X_scaled) > 0.5).astype("int32")
# Out:
# 1/1 [==============================] - 0s 41ms/step
# array([[0],
#        [1],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1],
#        [0]])

# %%
from sklearn.datasets import make_moons

# Creating dummy nonlinear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# Creating a DataFrame to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons

# Plot the nonlinear dummy data
df_moons.plot.scatter(x="Feature 1",y="Feature 2", c="Target",colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# Create the scaler instance
X_moon_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_moon_scaler.fit(X_moon_train)

# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %%
# Training the model with the nonlinear data
model_moon = nn_model.fit(X_moon_train_scaled, y_moon_train, epochs=100, shuffle=True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 703us/step - loss: 0.8378 - accuracy: 0.5627
# Epoch 2/100
# 24/24 [==============================] - 0s 700us/step - loss: 0.7348 - accuracy: 0.5907
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6616 - accuracy: 0.6187
# Epoch 4/100
# 24/24 [==============================] - 0s 739us/step - loss: 0.6090 - accuracy: 0.6427
# Epoch 5/100
# 24/24 [==============================] - 0s 700us/step - loss: 0.5685 - accuracy: 0.6680
# Epoch 6/100
# 24/24 [==============================] - 0s 695us/step - loss: 0.5367 - accuracy: 0.6800
# Epoch 7/100
# 24/24 [==============================] - 0s 697us/step - loss: 0.5100 - accuracy: 0.6987
# Epoch 8/100
# 24/24 [==============================] - 0s 695us/step - loss: 0.4867 - accuracy: 0.7120
# 24/24 [==============================] - 0s 737us/step - loss: 0.2654 - accuracy: 0.8893
# Epoch 72/100
# 24/24 [==============================] - 0s 743us/step - loss: 0.2650 - accuracy: 0.8893
# Epoch 73/100
# 24/24 [==============================] - 0s 740us/step - loss: 0.2648 - accuracy: 0.8893
# Epoch 74/100
# 24/24 [==============================] - 0s 738us/step - loss: 0.2644 - accuracy: 0.8893
# Epoch 75/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.2640 - accuracy: 0.8920
# Epoch 76/100
# 24/24 [==============================] - 0s 824us/step - loss: 0.2639 - accuracy: 0.8907
# Epoch 77/100
# 24/24 [==============================] - 0s 741us/step - loss: 0.2635 - accuracy: 0.8920
# Epoch 78/100
# 24/24 [==============================] - 0s 786us/step - loss: 0.2633 - accuracy: 0.8920
# Epoch 79/100
# 24/24 [==============================] - 0s 790us/step - loss: 0.2630 - accuracy: 0.8920
# Epoch 80/100
# 24/24 [==============================] - 0s 780us/step - loss: 0.2626 - accuracy: 0.8933
# Epoch 81/100
# 24/24 [==============================] - 0s 786us/step - loss: 0.2624 - accuracy: 0.8933
# Epoch 82/100
# 24/24 [==============================] - 0s 869us/step - loss: 0.2622 - accuracy: 0.8933
# Epoch 83/100
# 24/24 [==============================] - 0s 784us/step - loss: 0.2620 - accuracy: 0.8933
# Epoch 84/100
# 24/24 [==============================] - 0s 782us/step - loss: 0.2618 - accuracy: 0.8933
# Epoch 85/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.2615 - accuracy: 0.8933
# Epoch 86/100
# 24/24 [==============================] - 0s 782us/step - loss: 0.2613 - accuracy: 0.8933
# Epoch 87/100
# 24/24 [==============================] - 0s 784us/step - loss: 0.2612 - accuracy: 0.8920
# Epoch 88/100
# 24/24 [==============================] - 0s 782us/step - loss: 0.2608 - accuracy: 0.8933
# Epoch 89/100
# 24/24 [==============================] - 0s 782us/step - loss: 0.2607 - accuracy: 0.8920
# Epoch 90/100
# 24/24 [==============================] - 0s 785us/step - loss: 0.2605 - accuracy: 0.8920
# Epoch 91/100
# 24/24 [==============================] - 0s 738us/step - loss: 0.2603 - accuracy: 0.8933
# Epoch 92/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.2601 - accuracy: 0.8947
# Epoch 93/100
# 24/24 [==============================] - 0s 740us/step - loss: 0.2600 - accuracy: 0.8933
# Epoch 94/100
# 24/24 [==============================] - 0s 782us/step - loss: 0.2597 - accuracy: 0.8933
# Epoch 95/100
# 24/24 [==============================] - 0s 812us/step - loss: 0.2596 - accuracy: 0.8933
# Epoch 96/100
# 24/24 [==============================] - 0s 783us/step - loss: 0.2595 - accuracy: 0.8933
# Epoch 97/100
# 24/24 [==============================] - 0s 785us/step - loss: 0.2594 - accuracy: 0.8920
# Epoch 98/100
# 24/24 [==============================] - 0s 782us/step - loss: 0.2591 - accuracy: 0.8933
# Epoch 99/100
# 24/24 [==============================] - 0s 784us/step - loss: 0.2589 - accuracy: 0.8933
# Epoch 100/100
# 24/24 [==============================] - 0s 779us/step - loss: 0.2588 - accuracy: 0.8920

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(model_moon.history, index=range(1,len(model_moon.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>
